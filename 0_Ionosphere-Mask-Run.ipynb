# %%
import json
from isce2_topsapp.iono_proc import iono_processing
from isce2_topsapp.localize_mask import download_water_mask
import matplotlib.pyplot as plt
import rasterio
import numpy as np
import logging
logging.getLogger().setLevel(logging.WARNING)
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# 2024-01-30 10:47:04,361 - matplotlib.font_manager - DEBUG - Using fontManager instance from /home/cmarshak/.cache/matplotlib/fontlist-v330.json

# %%
loc_data = json.load(open('loc_data.json'))
loc_data
# Out:
# {'reference_scenes': ['S1A_IW_SLC__1SDV_20220212T222803_20220212T222830_041886_04FCA3_2B3E',
#   'S1A_IW_SLC__1SDV_20220212T222828_20220212T222855_041886_04FCA3_A3E2'],
#  'secondary_scenes': ['S1A_IW_SLC__1SDV_20220131T222803_20220131T222830_041711_04F690_8F5F',
#   'S1A_IW_SLC__1SDV_20220131T222828_20220131T222855_041711_04F690_28D7'],
#  'frame_id': 25502,
#  'ref_paths': ['S1A_IW_SLC__1SDV_20220212T222828_20220212T222855_041886_04FCA3_A3E2.zip',
#   'S1A_IW_SLC__1SDV_20220212T222803_20220212T222830_041886_04FCA3_2B3E.zip'],
#  'sec_paths': ['S1A_IW_SLC__1SDV_20220131T222828_20220131T222855_041711_04F690_28D7.zip',
#   'S1A_IW_SLC__1SDV_20220131T222803_20220131T222830_041711_04F690_8F5F.zip'],
#  'extent': [-71.32807577094489,
#   47.35015226169008,
#   -67.47945065650076,
#   49.14396169772953],
#  'gunw_geo': {'type': 'Polygon',
#   'coordinates': [[[-67.56389051312044, 47.852140949747735],
#     [-67.47945065650076, 47.48175879127325],
#     [-67.99492534034955, 47.429567703811465],
#     [-68.52987513855085, 47.37275123696082],
#     [-68.55727989287345, 47.48198524930101],
#     [-69.09896846019329, 47.421616017501826],
#     [-69.70919700836623, 47.35015226169008],
#     [-69.78111489146, 47.613618796674885],
#     [-70.29087990731554, 47.55199732126649],
#     [-70.87876693003453, 47.47767780134041],
#     [-71.1335260373605, 48.33245909620376],
#     [-71.17732771160051, 48.497691935550456],
#     [-71.32807577094489, 48.9934664193567],
#     [-70.72357418792893, 49.073063410471164],
#     [-70.1620736681961, 49.14396169772953],
#     [-70.08244510661609, 48.861110698101],
#     [-69.49265888652626, 48.93246094155771],
#     [-68.89930636351852, 49.001024725991755],
#     [-68.87209673148254, 48.89524681271839],
#     [-68.35882950083834, 48.952510206796376],
#     [-67.82862731394724, 49.00911898266449],
#     [-67.78063949294818, 48.80414813817185],
#     [-67.7838829742832, 48.803513684598364],
#     [-67.56389051312044, 47.852140949747735]]]},
#  'processing_extent': [-71.28001910050304,
#   47.67792128636605,
#   -67.52426023284436,
#   48.83690336500213],
#  'reference_properties': [{'centerLat': 47.7699,
#    'centerLon': -69.2573,
#    'stopTime': '2022-02-12T22:28:55.000Z',
#    'fileID': 'S1A_IW_SLC__1SDV_20220212T222828_20220212T222855_041886_04FCA3_A3E2-SLC',
#    'flightDirection': 'ASCENDING',
#    'pathNumber': 164,
#    'processingLevel': 'SLC',
#    'url': 'https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_SLC__1SDV_20220212T222828_20220212T222855_041886_04FCA3_A3E2.zip',
#    'startTime': '2022-02-12T22:28:28.000Z',
#    'sceneName': 'S1A_IW_SLC__1SDV_20220212T222828_20220212T222855_041886_04FCA3_A3E2',
#    'browse': None,
#    'platform': 'Sentinel-1A',
#    'bytes': 4468269588,
#    'md5sum': '7cf88ca495d436cf48f3b8c271408219',
#    'frameNumber': 152,
#    'granuleType': 'SENTINEL_1A_FRAME',
#    'orbit': 41886,
#    'polarization': 'VV+VH',
#    'processingDate': '2022-02-12T22:28:28.000Z',
#    'sensor': 'C-SAR',
#    'groupID': 'S1A_IWDV_0152_0158_041886_164',
#    'pgeVersion': '003.40',
#    'fileName': 'S1A_IW_SLC__1SDV_20220212T222828_20220212T222855_041886_04FCA3_A3E2.zip',
#    'beamModeType': 'IW'},
#   {'centerLat': 46.282,
#    'centerLon': -68.8748,
#    'stopTime': '2022-02-12T22:28:30.000Z',
#    'fileID': 'S1A_IW_SLC__1SDV_20220212T222803_20220212T222830_041886_04FCA3_2B3E-SLC',
#    'flightDirection': 'ASCENDING',
#    'pathNumber': 164,
#    'processingLevel': 'SLC',
#    'url': 'https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_SLC__1SDV_20220212T222803_20220212T222830_041886_04FCA3_2B3E.zip',
#    'startTime': '2022-02-12T22:28:03.000Z',
#    'sceneName': 'S1A_IW_SLC__1SDV_20220212T222803_20220212T222830_041886_04FCA3_2B3E',
#    'browse': None,
#    'platform': 'Sentinel-1A',
#    'bytes': 4567417302,
#    'md5sum': '8cdade2046e85c86e9ec733eac46c623',
#    'frameNumber': 147,
#    'granuleType': 'SENTINEL_1A_FRAME',
#    'orbit': 41886,
#    'polarization': 'VV+VH',
#    'processingDate': '2022-02-12T22:28:03.000Z',
#    'sensor': 'C-SAR',
#    'groupID': 'S1A_IWDV_0147_0153_041886_164',
#    'pgeVersion': '003.40',
#    'fileName': 'S1A_IW_SLC__1SDV_20220212T222803_20220212T222830_041886_04FCA3_2B3E.zip',
#    'beamModeType': 'IW'}],
#  'secondary_properties': [{'centerLat': 47.7703,
#    'centerLon': -69.2557,
#    'stopTime': '2022-01-31T22:28:55.000Z',
#    'fileID': 'S1A_IW_SLC__1SDV_20220131T222828_20220131T222855_041711_04F690_28D7-SLC',
#    'flightDirection': 'ASCENDING',
#    'pathNumber': 164,
#    'processingLevel': 'SLC',
#    'url': 'https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_SLC__1SDV_20220131T222828_20220131T222855_041711_04F690_28D7.zip',
#    'startTime': '2022-01-31T22:28:28.000Z',
#    'sceneName': 'S1A_IW_SLC__1SDV_20220131T222828_20220131T222855_041711_04F690_28D7',
#    'browse': None,
#    'platform': 'Sentinel-1A',
#    'bytes': 4420178111,
#    'md5sum': 'b6d5b52910b63c3e2afb3327f227f0c8',
#    'frameNumber': 152,
#    'granuleType': 'SENTINEL_1A_FRAME',
#    'orbit': 41711,
#    'polarization': 'VV+VH',
#    'processingDate': '2022-01-31T22:28:28.000Z',
#    'sensor': 'C-SAR',
#    'groupID': 'S1A_IWDV_0152_0158_041711_164',
#    'pgeVersion': '003.40',
#    'fileName': 'S1A_IW_SLC__1SDV_20220131T222828_20220131T222855_041711_04F690_28D7.zip',
#    'beamModeType': 'IW'},
#   {'centerLat': 46.2827,
#    'centerLon': -68.8732,
#    'stopTime': '2022-01-31T22:28:30.000Z',
#    'fileID': 'S1A_IW_SLC__1SDV_20220131T222803_20220131T222830_041711_04F690_8F5F-SLC',
#    'flightDirection': 'ASCENDING',
#    'pathNumber': 164,
#    'processingLevel': 'SLC',
#    'url': 'https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_SLC__1SDV_20220131T222803_20220131T222830_041711_04F690_8F5F.zip',
#    'startTime': '2022-01-31T22:28:03.000Z',
#    'sceneName': 'S1A_IW_SLC__1SDV_20220131T222803_20220131T222830_041711_04F690_8F5F',
#    'browse': None,
#    'platform': 'Sentinel-1A',
#    'bytes': 4432311620,
#    'md5sum': 'e943b8096ce67a88f474f313cac08376',
#    'frameNumber': 147,
#    'granuleType': 'SENTINEL_1A_FRAME',
#    'orbit': 41711,
#    'polarization': 'VV+VH',
#    'processingDate': '2022-01-31T22:28:03.000Z',
#    'sensor': 'C-SAR',
#    'groupID': 'S1A_IWDV_0147_0153_041711_164',
#    'pgeVersion': '003.40',
#    'fileName': 'S1A_IW_SLC__1SDV_20220131T222803_20220131T222830_041711_04F690_8F5F.zip',
#    'beamModeType': 'IW'}],
#  'extent_buffered': [-72.0, 46.0, -67.0, 50.0],
#  'full_res_dem_path': 'full_res.dem.wgs84',
#  'low_res_dem_path': 'low_res.dem.wgs84',
#  'water_mask': 'water_mask_derived_from_esa_world_cover_2021_10m',
#  'aux_cal_dir': 'aux_cal',
#  'orbit_directory': 'orbits',
#  'reference_orbits': ['orbits/S1A_OPER_AUX_POEORB_OPOD_20220304T081601_V20220211T225942_20220213T005942.EOF'],
#  'secondary_orbits': ['orbits/S1A_OPER_AUX_POEORB_OPOD_20220220T081616_V20220130T225942_20220201T005942.EOF'],
#  'cmd_line_str': 'isce2_topsapp ++gunw_slc --secondary-scenes S1A_IW_SLC__1SDV_20220131T222803_20220131T222830_041711_04F690_8F5F S1A_IW_SLC__1SDV_20220131T222828_20220131T222855_041711_04F690_28D7 --reference-scenes S1A_IW_SLC__1SDV_20220212T222803_20220212T222830_041886_04FCA3_2B3E S1A_IW_SLC__1SDV_20220212T222828_20220212T222855_041886_04FCA3_A3E2 --frame-id 25502',
#  'tops_app_params': {'reference_scenes': ['S1A_IW_SLC__1SDV_20220212T222803_20220212T222830_041886_04FCA3_2B3E',
#    'S1A_IW_SLC__1SDV_20220212T222828_20220212T222855_041886_04FCA3_A3E2'],
#   'secondary_scenes': ['S1A_IW_SLC__1SDV_20220131T222803_20220131T222830_041711_04F690_8F5F',
#    'S1A_IW_SLC__1SDV_20220131T222828_20220131T222855_041711_04F690_28D7'],
#   'frame_id': 25502,
#   'estimate_ionosphere_delay': True,
#   'compute_solid_earth_tide': True,
#   'output_resolution': 90,
#   'unfiltered_coherence': True,
#   'goldstein_filter_power': 0.5,
#   'dense_offsets': False,
#   'esd_coherence_threshold': -1.0}}

# %%
extent = loc_data['extent_buffered']
wm_path_data = download_water_mask(extent)
wm_path_data
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# fixing xml file path for file: water_mask_derived_from_esa_world_cover_2021_10m.geo
# Writing geotrans to VRT for /mnt/leffe-data2/cmarshak/Jan2024-topsapp-revision/water_mask_derived_from_esa_world_cover_2021_10m.geo
# {'water_mask': 'water_mask_derived_from_esa_world_cover_2021_10m.geo'}

# %%
# !ls *.vrt
# Out:
# full_res.dem.wgs84.vrt
# low_res.dem.wgs84.vrt
# water_mask_derived_from_esa_world_cover_2021_10m.geo.vrt
# water_mask_derived_from_esa_world_cover_2021_10m.tif.vrt
# water_mask_derived_from_esa_world_cover_2021_10m.vrt

# %%
WM_PATH = wm_path_data['water_mask']
WM_PATH
# Out:
# 'water_mask_derived_from_esa_world_cover_2021_10m.geo'

# %%
with rasterio.open(WM_PATH + '.vrt') as ds:
    p = ds.profile
p
# Out:
# {'driver': 'VRT', 'dtype': 'uint8', 'nodata': None, 'width': 84000, 'height': 72000, 'count': 1, 'crs': CRS.from_epsg(4326), 'transform': Affine(8.33333e-05, 0.0, -73.0,
#        0.0, -8.33333e-05, 51.0), 'blockysize': 1, 'tiled': False}

# %%
iono_attr = iono_processing(
            mask_filename=WM_PATH,
            correct_burst_ramps=True,
        )
# Out:
# 2024-01-30 10:54:13,883 - isce.insar - INFO - ISCE VERSION = 2.6.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20220811, CURRENT_SVN_REVISION =
# ISCE VERSION = 2.6.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20220811, CURRENT_SVN_REVISION =
#
# 2024-01-30 10:54:13,914 - isce.insar - WARNING - Some filenames in insarApp.geocode_list configuration are different from those in InsarProc. Using names given to insarApp.
# insarApp.geocode_list = ['merged/phsig.cor', 'merged/filt_topophase.unw', 'merged/los.rdr', 'merged/topophase.flat', 'merged/filt_topophase.flat', 'merged/filt_topophase_2stage.unw', 'merged/topophase.cor', 'merged/filt_topophase.unw.conncomp']
# InsarProc.geocode_list = ['merged/phsig.cor', 'merged/topophase.cor', 'merged/filt_topophase.unw', 'merged/los.rdr', 'merged/topophase.flat', 'merged/filt_topophase.flat', 'merged/filt_topophase_2stage.unw']
# processing subband burst interferograms
# Shifts IW-1:  {0: 0, 1: -1, 2: -2, 3: -2, 4: -1}
# processing reference burst: 01, secondary burst: 01, swath: 1
# processing line:   1499 of   1499
#
# processing line:   1000 of   1499
# Chi squared: 0.000028
# Misfit radians - Max: 9.25194672163343e-05 , Min : -0.00017206539268954657
# 2024-01-30 10:54:43,534 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1499 which is the number of lines in the slc image.
# 2024-01-30 10:54:43,535 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 21800 which is the width of the slc image.
# 2024-01-30 10:54:43,536 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# processing line:   1499 of   1499
# No Range Carrier provided.
# Assuming zero range carrier.
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# file width: 21800, file length: 1499
#
# inputfile byte order: little endian
# input file image offset [byte]: 0
# input file line offset [byte]: 174400
# file width: 21800, file length: 1499
#
# inputfile byte order: little endian
# input file image offset [byte]: 0
# input file line offset [byte]: 174400
# Polynomial Order: 5 - by - 3
# 13240.1	-670.818	24.5663	0.957941
# -51263.4	2572.46	-103.172	-3.78514
# 49620.8	-2465.99	107.673	3.74935
# -3.91577e-09	4.58013e-09	-1.59755e-09	0
# 2.69972e-09	-1.33869e-09	0	0
# -7.10213e-10	0	0	0
# GDAL open (R): ion/lower/fine_interferogram/IW1/secondary_burst_01.slc.vrt
# API open (WR): ion/lower/fine_interferogram/IW1/secondary_resamp_burst_01.slc
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 
# API close:  ion/lower/fine_interferogram/IW1/secondary_resamp_burst_05.slc
# API open (R): ion/lower/fine_interferogram/IW1/secondary_resamp_burst_05.slc
# API close:  ion/lower/fine_interferogram/IW1/secondary_resamp_burst_05.slc
# Adjust valid samples
# Before:  781 20420
# Offsets :  -32.26951599121094 -26.751102447509766
# Adjust valid lines
# Before:  19 1463
# Offsets :  -3.1079020500183105 -3.0827555656433105
# 2024-01-30 10:58:01,811 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1499 which is the number of lines in the slc image.
# 2024-01-30 10:58:01,813 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 21800 which is the width of the slc image.
# 2024-01-30 10:58:01,814 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# No Range Carrier provided.
# Assuming zero range carrier.
# GDAL open (R): ion/upper/fine_interferogram/IW1/secondary_burst_05.slc.vrt
# API open (WR): ion/upper/fine_interferogram/IW1/secondary_resamp_burst_05.slc
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 13203.3	-714.596	15.4252	0.912153
# -51189.2	2657.6	-85.3718	-3.61968
# 49615.2	-2466.46	107.744	3.7523
# -4.04356e-09	4.56615e-09	-1.53963e-09	0
# 2.81849e-09	-1.35024e-09	0	0
# -7.58396e-10	0	0	0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# GDAL open (R): fine_offsets/IW1/range_05.off.vrt
# GDAL open (R): fine_offsets/IW1/azimuth_05.off.vrt
# Polynomial Order: 0 - by - 2
# 0.327275	-373.086	-182596
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#        21800  pixels
#         1499 lines
#
#  Output Image Dimensions:
#        21800 pixels
#         1499 lines
#
#  Number of threads:            8
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 13203.3	-714.596	15.4252	0.912153
# -51189.2	2657.6	-85.3718	-3.61968
# 49615.2	-2466.46	107.744	3.7523
# -4.04356e-09	4.56615e-09	-1.53963e-09	0
# 2.81849e-09	-1.35024e-09	0	0
# -7.58396e-10	0	0	0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Doppler poly
# Polynomial Order: 0 - by - 2
# 0.327275	-373.086	-182596
#  Reading in the image
#  At line         1000
#  Interpolating image
#  At line         1000
#  Elapsed time:    6.89453125
# GDAL close: fine_offsets/IW1/range_05.off.vrt
# GDAL close: fine_offsets/IW1/azimuth_05.off.vrt
# GDAL close: ion/upper/fine_interferogram/IW1/secondary_burst_05.slc.vrt
# API close:  ion/upper/fine_interferogram/IW1/secondary_resamp_burst_05.slc
# API open (R): ion/upper/fine_interferogram/IW1/secondary_resamp_burst_05.slc
# API close:  ion/upper/fine_interferogram/IW1/secondary_resamp_burst_05.slc
# Adjust valid samples
# Before:  781 20420
# Offsets :  -32.26951599121094 -26.751102447509766
# Adjust valid lines
# Before:  19 1463
# Offsets :  -3.1079020500183105 -3.0827555656433105
# Shifts IW-2:  {1: 0, 2: 2, 3: 0, 4: -1, 5: 0, 6: -3}
# processing reference burst: 01, secondary burst: 02, swath: 2
# processing line:   1510 of   1510
#
# processing line:   1000 of   1510
# Chi squared: 0.000037
# Misfit radians - Max: 0.00011731085760402493 , Min : -0.0002280931166751543
# 2024-01-30 10:59:02,921 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1510 which is the number of lines in the slc image.
# 2024-01-30 10:59:02,922 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 25660 which is the width of the slc image.
# 2024-01-30 10:59:02,923 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# processing line:   1510 of   1510
# No Range Carrier provided.
# Assuming zero range carrier.
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# file width: 25660, file length: 1510
#
# inputfile byte order: little endian
# input file image offset [byte]: 0
# input file line offset [byte]: 205280
# file width: 25660, file length: 1510
#
# inputfile byte order: little endian
# input file image offset [byte]: 0
# input file line offset [byte]: 205280
# Polynomial Order: 5 - by - 3
# 11286.6	-594.295	34.2054	1.63575
# -44847.3	2291.08	-113.97	-5.97914
# 44550.3	-2206.02	91.5148	5.37353
# -2.2003e-09	2.1679e-09	-5.06127e-10	0
# 1.62076e-09	-7.51113e-10	0	0
# -4.0932e-10	0	0	0
# GDAL open (R): ion/lower/fine_interferogram/IW2/secondary_burst_02.slc.vrt
# API open (WR): ion/lower/fine_interferogram/IW2/secondary_resamp_burst_02.slc
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11286.6	-594.295	34.2054	1.63575
# -44847.3	2291.08	-113.97	-5.97914
# 44550.3	-2206.02	91.5148	5.37353
# -2.2003e-09	2.1679e-09	-5.06127e-10	0
# 1.62076e-09	-7.51113e-10	0	0
# -4.0932e-10	0	0	0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# GDAL open (R): fine_offsets/IW2/range_01.off.vrt
# GDAL open (R): fine_offsets/IW2/azimuth_01.off.vrt
# Polynomial Order: 0 - by - 2
# 0.389057	-322.329	155257
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#        25660  pixels
#         1510 lines
#
#  Output Image Dimensions:
#        25660 pixels
#         1510 lines
#
#  Number of threads:            8
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 11286.6	-594.295	34.2054	1.63575
# -44847.3	2291.08	-113.97	-5.97914
# 44550.3	-2206.02	91.5148	5.37353
# -2.2003e-09	2.1679e-09	-5.06127e-10	0
# 1.62076e-09	-7.51113e-10	0	0
# -4.0932e-10	0	0	0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Doppler poly
# Polynomial Order: 0 - by - 2
# 0.389057	-322.329	155257
#  Reading in the image
#  At line         1000
#  Interpolating image
#  At line         1000
#  Elapsed time:    9.57421875
# GDAL close: fine_offsets/IW2/range_01.off.vrt
# GDAL close: fine_offsets/IW2/azimuth_01.off.vrt
# GDAL close: ion/lower/fine_interferogram/IW2/secondary_burst_02.slc.vrt
# API close:  ion/lower/fine_interferogram/IW2/secondary_resamp_burst_02.slc
# API open (R): ion/lower/fine_interferogram/IW2/secondary_resamp_burst_02.slc
# API close:  ion/lower/fine_interferogram/IW2/secondary_resamp_burst_02.slc
# Adjust valid samples
# Before:  711 24392
# Offsets :  -36.62914276123047 -31.859886169433594
# Adjust valid lines
# Before:  25 1461
# Offsets :  -4.087353229522705 -4.059909820556641
# 2024-01-30 10:59:15,794 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1510 which is the number of lines in the slc image.
# 2024-01-30 10:59:15,796 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 25660 which is the width of the slc image.
# 2024-01-30 10:59:15,797 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# No Range Carrier provided.
# Assuming zero range carrier.
# GDAL open (R): ion/upper/fine_interferogram/IW2/secondary_burst_02.slc.vrt
# API open (WR): ion/upper/fine_interferogram/IW2/secondary_resamp_burst_02.slc
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11286.6	-594.295	34.2054	1.63575
# -44847.3	2291.08	-113.97	-5.97914
# 44550.3	-2206.02	91.5148	5.37353
# -2.2003e-09	2.1679e-09	-5.06127e-10	0
# 1.62076e-09	-7.51113e-10	0	0
# -4.0932e-10	0	0	0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# GDAL open (R): fine_offsets/IW2/range_01.off.vrt
# GDAL open (R): fine_offsets/IW2/azimuth_01.off.vrt
# Polynomial Order: 0 - by - 2
# 0.389057	-322.329	155257
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#        25660  pixels
#         1510 lines
#
#  Output Image Dimensions:
#        25660 pixels
#         1510 lines
#
#  Number of threads:            8
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 11286.6	-594.295	34.2054	1.63575
# -44847.3	2291.08	-113.97	-5.97914
# 44550.3	-2206.02	91.5148	5.37353
# -2.2003e-09	2.1679e-09	-5.06127e-10	0
# 1.62076e-09	-7.51113e-10	0	0
# -4.0932e-10	0	0	0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Doppler poly
# Polynomial Order: 0 - by - 2
# 0.389057	-322.329	155257
#  Reading in the image
#  At line         1000
#  Interpolating image
#  At line         1000
#  Elapsed time:    9.70703125
# GDAL close: fine_offsets/IW2/range_01.off.vrt
# GDAL close: fine_offsets/IW2/azimuth_01.off.vrt
# GDAL close: ion/upper/fine_interferogram/IW2/secondary_burst_02.slc.vrt
# API close:  ion/upper/fine_interferogram/IW2/secondary_resamp_burst_02.slc
# API open (R): ion/upper/fine_interferogram/IW2/secondary_resamp_burst_02.slc
# API close:  ion/upper/fine_interferogram/IW2/secondary_resamp_burst_02.slc
# Adjust valid samples
# Before:  711 24392
# Offsets :  -36.62914276123047 -31.859886169433594
# Adjust valid lines
# Before:  25 1461
# Offsets :  -4.087353229522705 -4.059909820556641
# processing reference burst: 02, secondary burst: 03, swath: 2
# processing line:   1510 of   1510
#
# processing line:   1000 of   1510
# Chi squared: 0.000025
# Misfit radians - Max: 9.141048940364271e-05 , Min : -0.000177928068296751
# 2024-01-30 10:59:59,676 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1510 which is the number of lines in the slc image.
# 2024-01-30 10:59:59,678 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 25660 which is the width of the slc image.
# 2024-01-30 10:59:59,679 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# processing line:   1510 of   1510
# No Range Carrier provided.
# Assuming zero range carrier.
# file width: 25660, file length: 1510
#
# inputfile byte order: little endian
# input file image offset [byte]: 0
# input file line offset [byte]: 205280
# file width: 25660, file length: 1510
#
# inputfile byte order: little endian
# input file image offset [byte]: 0
# input file line offset [byte]: 205280
# Polynomial Order: 5 - by - 3
# 11346.2	-584.388	17.9935	1.29974
# -44965.1	2271.32	-81.8238	-5.27194
# 44549.3	-2206.11	91.5237	5.37424
# -1.95911e-09	1.82954e-09	-4.43844e-10	0
# 1.48314e-09	-6.08642e-10	0	0
# -3.93724e-10	0	0	0
# GDAL open (R): ion/lower/fine_interferogram/IW2/secondary_burst_03.slc.vrt
# API open (WR): ion/lower/fine_interferogram/IW2/secondary_resamp_burst_03.slc
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11346.2	-584.388	17.9935	1.29974
# -44965.1	2271.32	-81.8238	-5.27194
# 44549.3	-2206.11	91.5237	5.37424
# -1.95911e-09	1.82954e-09	-4.43844e-10	0
# 1.48314e-09	-6.08642e-10	0	0
# -3.93724e-10	0	0	0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# GDAL open (R): fine_offsets/IW2/range_02.off.vrt
# GDAL open (R): fine_offsets/IW2/azimuth_02.off.vrt
# Polynomial Order: 0 - by - 2
# 0.32123	-130.84	-50904.5
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#        25660  pixels
#         1510 lines
#
#  Output Image Dimensions:
#        25660 pixels
#         1510 lines
#
#  Number of threads:            8
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 11346.2	-584.388	17.9935	1.29974
# -44965.1	2271.32	-81.8238	-5.27194
# 44549.3	-2206.11	91.5237	5.37424
# -1.95911e-09	1.82954e-09	-4.43844e-10	0
# 1.48314e-09	-6.08642e-10	0	0
# -3.93724e-10	0	0	0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Doppler poly
# Polynomial Order: 0 - by - 2
# 0.32123	-130.84	-50904.5
#  Reading in the image
#  At line         1000
#  Interpolating image
#  At line         1000
#  Elapsed time:    9.22656250
# GDAL close: fine_offsets/IW2/range_02.off.vrt
# GDAL close: fine_offsets/IW2/azimuth_02.off.vrt
# GDAL close: ion/lower/fine_interferogram/IW2/secondary_burst_03.slc.vrt
# API close:  ion/lower/fine_interferogram/IW2/secondary_resamp_burst_03.slc
# API open (R): ion/lower/fine_interferogram/IW2/secondary_resamp_burst_03.slc
# API close:  ion/lower/fine_interferogram/IW2/secondary_resamp_burst_03.slc
# Adjust valid samples
# Before:  711 24392
# Offsets :  -36.62713623046875 -31.850671768188477
# Adjust valid lines
# Before:  26 1461
# Offsets :  -8.086877822875977 -8.059804916381836
# 2024-01-30 11:00:12,009 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1510 which is the number of lines in the slc image.
# 2024-01-30 11:00:12,013 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 25660 which is the width of the slc image.
# 2024-01-30 11:00:12,014 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# No Range Carrier provided.
# Assuming zero range carrier.
# GDAL open (R): ion/upper/fine_interferogram/IW2/secondary_burst_03.slc.vrt
# API open (WR): ion/upper/fine_interferogram/IW2/secondary_resamp_burst_03.slc
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11346.2	-584.388	17.9935	1.29974
# -44965.1	2271.32	-81.8238	-5.27194
# 44549.3	-2206.11	91.5237	5.37424
# -1.95911e-09	1.82954e-09	-4.43844e-10	0
# 1.48314e-09	-6.08642e-10	0	0
# -3.93724e-10	0	0	0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# GDAL open (R): fine_offsets/IW2/range_02.off.vrt
# GDAL open (R): fine_offsets/IW2/azimuth_02.off.vrt
# Polynomial Order: 0 - by - 2
# 0.32123	-130.84	-50904.5
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#        25660  pixels
#         1510 lines
#
#  Output Image Dimensions:
#        25660 pixels
#         1510 lines
#
#  Number of threads:            8
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 11346.2	-584.388	17.9935	1.29974
# -44965.1	2271.32	-81.8238	-5.27194
# 44549.3	-2206.11	91.5237	5.37424
# -1.95911e-09	1.82954e-09	-4.43844e-10	0
# 1.48314e-09	-6.08642e-10	0	0
# -3.93724e-10	0	0	0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Doppler poly
# Polynomial Order: 0 - by - 2
# 0.32123	-130.84	-50904.5
#  Reading in the image
#  At line         1000
#  Interpolating image
#  At line         1000
#  Elapsed time:    9.05078125
# GDAL close: fine_offsets/IW2/range_02.off.vrt
# GDAL close: fine_offsets/IW2/azimuth_02.off.vrt
# GDAL close: ion/upper/fine_interferogram/IW2/secondary_burst_03.slc.vrt
# API close:  ion/upper/fine_interferogram/IW2/secondary_resamp_burst_03.slc
# API open (R): ion/upper/fine_interferogram/IW2/secondary_resamp_burst_03.slc
# API close:  ion/upper/fine_interferogram/IW2/secondary_resamp_burst_03.slc
# Adjust valid samples
# Before:  711 24392
# Offsets :  -36.62713623046875 -31.850671768188477
# Adjust valid lines
# Before:  26 1461
# Offsets :  -8.086877822875977 -8.059804916381836
# processing reference burst: 03, secondary burst: 04, swath: 2
# processing line:   1510 of   1510
#
# processing line:   1000 of   1510
# Chi squared: 0.000028
# Misfit radians - Max: 9.844933811109513e-05 , Min : -0.0001915619504870847
# 2024-01-30 11:00:55,144 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1510 which is the number of lines in the slc image.
# 2024-01-30 11:00:55,145 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 25660 which is the width of the slc image.
# 2024-01-30 11:00:55,146 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# processing line:   1510 of   1510
# No Range Carrier provided.
# Assuming zero range carrier.
# file width: 25660, file length: 1510
#
# inputfile byte order: little endian
# input file image offset [byte]: 0
# input file line offset [byte]: 205280
# file width: 25660, file length: 1510
#
# inputfile byte order: little endian
# input file image offset [byte]: 0
# input file line offset [byte]: 205280
# Polynomial Order: 5 - by - 3
# 11286.2	-575.526	16.3109	1.25115
# -44845.9	2253.88	-78.4671	-5.17437
# 44548.9	-2206.2	91.5289	5.37483
# -2.2694e-09	2.30991e-09	-5.93741e-10	0
# 1.61405e-09	-7.61516e-10	0	0
# -3.90741e-10	0	0	0
# GDAL open (R): ion/lower/fine_interferogram/IW2/secondary_burst_04.slc.vrt
# API open (WR): ion/lower/fine_interferogram/IW2/secondary_resamp_burst_04.slc
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11286.2	-575.526	16.3109	1.25115
# -44845.9	2253.88	-78.4671	-5.17437
# 44548.9	-2206.2	91.5289	5.37483
# -2.2694e-09	2.30991e-09	-5.93741e-10	0
# 1.61405e-09	-7.61516e-10	0	0
# -3.90741e-10	0	0	0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# GDAL open (R): fine_offsets/IW2/range_03.off.vrt
# GDAL open (R): fine_offsets/IW2/azimuth_03.off.vrt
# Polynomial Order: 0 - by - 2
# 0.278111	-83.3426	-72909.6
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#        25660  pixels
#         1510 lines
#
#  Output Image Dimensions:
#        25660 pixels
#         1510 lines
#
#  Number of threads:            8
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 11286.2	-575.526	16.3109	1.25115
# -44845.9	2253.88	-78.4671	-5.17437
# 44548.9	-2206.2	91.5289	5.37483
# -2.2694e-09	2.30991e-09	-5.93741e-10	0
# 1.61405e-09	-7.61516e-10	0	0
# -3.90741e-10	0	0	0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Doppler poly
# Polynomial Order: 0 - by - 2
# 0.278111	-83.3426	-72909.6
#  Reading in the image
#  At line         1000
#  Interpolating image
#  At line         1000
#  Elapsed time:    9.26171875
# GDAL close: fine_offsets/IW2/range_03.off.vrt
# GDAL close: fine_offsets/IW2/azimuth_03.off.vrt
# GDAL close: ion/lower/fine_interferogram/IW2/secondary_burst_04.slc.vrt
# API close:  ion/lower/fine_interferogram/IW2/secondary_resamp_burst_04.slc
# API open (R): ion/lower/fine_interferogram/IW2/secondary_resamp_burst_04.slc
# API close:  ion/lower/fine_interferogram/IW2/secondary_resamp_burst_04.slc
# Adjust valid samples
# Before:  711 24392
# Offsets :  -36.61848068237305 -31.850671768188477
# Adjust valid lines
# Before:  25 1461
# Offsets :  -4.0864644050598145 -4.059889316558838
# 2024-01-30 11:01:07,522 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1510 which is the number of lines in the slc image.
# 2024-01-30 11:01:07,523 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 25660 which is the width of the slc image.
# 2024-01-30 11:01:07,524 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# No Range Carrier provided.
# Assuming zero range carrier.
# GDAL open (R): ion/upper/fine_interferogram/IW2/secondary_burst_04.slc.vrt
# API open (WR): ion/upper/fine_interferogram/IW2/secondary_resamp_burst_04.slc
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11286.2	-575.526	16.3109	1.25115
# -44845.9	2253.88	-78.4671	-5.17437
# 44548.9	-2206.2	91.5289	5.37483
# -2.2694e-09	2.30991e-09	-5.93741e-10	0
# 1.61405e-09	-7.61516e-10	0	0
# -3.90741e-10	0	0	0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# GDAL open (R): fine_offsets/IW2/range_03.off.vrt
# GDAL open (R): fine_offsets/IW2/azimuth_03.off.vrt
# Polynomial Order: 0 - by - 2
# 0.278111	-83.3426	-72909.6
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#        25660  pixels
#         1510 lines
#
#  Output Image Dimensions:
#        25660 pixels
#         1510 lines
#
#  Number of threads:            8
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 11286.2	-575.526	16.3109	1.25115
# -44845.9	2253.88	-78.4671	-5.17437
# ...
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 11864.3	-628.374	18.6121	0.857042
# -47143	2432.18	-87.8531	-3.4848
# 46830.8	-2351.83	101.156	3.59674
# -2.49203e-09	2.8608e-09	-9.46953e-10	0
# 1.69351e-09	-8.52868e-10	0	0
# -4.22899e-10	0	0	0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Doppler poly
# Polynomial Order: 0 - by - 2
# 0.278111	-83.3426	-72909.6
#  Reading in the image
#  At line         1000
#  Interpolating image
#  At line         1000
#  Elapsed time:    9.25000000
# GDAL close: fine_offsets/IW3/range_04.off.vrt
# GDAL close: fine_offsets/IW3/azimuth_04.off.vrt
# GDAL close: ion/lower/fine_interferogram/IW3/secondary_burst_04.slc.vrt
# API close:  ion/lower/fine_interferogram/IW3/secondary_resamp_burst_04.slc
# API open (R): ion/lower/fine_interferogram/IW3/secondary_resamp_burst_04.slc
# API close:  ion/lower/fine_interferogram/IW3/secondary_resamp_burst_04.slc
# Adjust valid samples
# Before:  629 23613
# Offsets :  -39.81696319580078 -36.318153381347656
# Adjust valid lines
# Before:  27 1461
# Offsets :  -2.0616698265075684 -2.038728713989258
# 2024-01-30 11:07:44,716 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1515 which is the number of lines in the slc image.
# 2024-01-30 11:07:44,717 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 24742 which is the width of the slc image.
# 2024-01-30 11:07:44,718 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# No Range Carrier provided.
# Assuming zero range carrier.
# GDAL open (R): ion/upper/fine_interferogram/IW3/secondary_burst_04.slc.vrt
# API open (WR): ion/upper/fine_interferogram/IW3/secondary_resamp_burst_04.slc
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11864.3	-628.374	18.6121	0.857042
# -47143	2432.18	-87.8531	-3.4848
# 46830.8	-2351.83	101.156	3.59674
# -2.49203e-09	2.8608e-09	-9.46953e-10	0
# 1.69351e-09	-8.52868e-10	0	0
# -4.22899e-10	0	0	0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# GDAL open (R): fine_offsets/IW3/range_04.off.vrt
# GDAL open (R): fine_offsets/IW3/azimuth_04.off.vrt
# Polynomial Order: 0 - by - 2
# 0.278111	-83.3426	-72909.6
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#        24742  pixels
#         1515 lines
#
#  Output Image Dimensions:
#        24742 pixels
#         1515 lines
#
#  Number of threads:            8
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 11864.3	-628.374	18.6121	0.857042
# -47143	2432.18	-87.8531	-3.4848
# 46830.8	-2351.83	101.156	3.59674
# -2.49203e-09	2.8608e-09	-9.46953e-10	0
# 1.69351e-09	-8.52868e-10	0	0
# -4.22899e-10	0	0	0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Doppler poly
# Polynomial Order: 0 - by - 2
# 0.278111	-83.3426	-72909.6
#  Reading in the image
#  At line         1000
#  Interpolating image
#  At line         1000
#  Elapsed time:    8.39843750
# GDAL close: fine_offsets/IW3/range_04.off.vrt
# GDAL close: fine_offsets/IW3/azimuth_04.off.vrt
# GDAL close: ion/upper/fine_interferogram/IW3/secondary_burst_04.slc.vrt
# API close:  ion/upper/fine_interferogram/IW3/secondary_resamp_burst_04.slc
# API open (R): ion/upper/fine_interferogram/IW3/secondary_resamp_burst_04.slc
# API close:  ion/upper/fine_interferogram/IW3/secondary_resamp_burst_04.slc
# Adjust valid samples
# Before:  629 23613
# Offsets :  -39.81696319580078 -36.318153381347656
# Adjust valid lines
# Before:  27 1461
# Offsets :  -2.0616698265075684 -2.038728713989258
# processing reference burst: 05, secondary burst: 05, swath: 3
# processing line:   1515 of   1515
#
# processing line:   1000 of   1515
# Chi squared: 0.000107
# Misfit radians - Max: 0.00038162139389896765 , Min : -0.00019980443903477862
# 2024-01-30 11:08:27,897 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1515 which is the number of lines in the slc image.
# 2024-01-30 11:08:27,899 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 24742 which is the width of the slc image.
# 2024-01-30 11:08:27,900 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# processing line:   1515 of   1515
# No Range Carrier provided.
# Assuming zero range carrier.
# file width: 24742, file length: 1515
#
# inputfile byte order: little endian
# input file image offset [byte]: 0
# input file line offset [byte]: 197936
# file width: 24742, file length: 1515
#
# inputfile byte order: little endian
# input file image offset [byte]: 0
# input file line offset [byte]: 197936
# Polynomial Order: 5 - by - 3
# 11863.8	-605.413	54.4748	1.35069
# -47140.9	2386.61	-159.193	-4.44237
# 46828.7	-2351.9	101.165	3.59711
# -2.51998e-09	3.07272e-09	-1.06146e-09	0
# 1.66032e-09	-9.04476e-10	0	0
# -3.9574e-10	0	0	0
# GDAL open (R): ion/lower/fine_interferogram/IW3/secondary_burst_05.slc.vrt
# API open (WR): ion/lower/fine_interferogram/IW3/secondary_resamp_burst_05.slc
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11863.8	-605.413	54.4748	1.35069
# -47140.9	2386.61	-159.193	-4.44237
# 46828.7	-2351.9	101.165	3.59711
# -2.51998e-09	3.07272e-09	-1.06146e-09	0
# 1.66032e-09	-9.04476e-10	0	0
# -3.9574e-10	0	0	0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# GDAL open (R): fine_offsets/IW3/range_05.off.vrt
# GDAL open (R): fine_offsets/IW3/azimuth_05.off.vrt
# Polynomial Order: 0 - by - 2
# 0.277228	-523.175	348350
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#        24742  pixels
#         1515 lines
#
#  Output Image Dimensions:
#        24742 pixels
#         1515 lines
#
#  Number of threads:            8
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 11863.8	-605.413	54.4748	1.35069
# -47140.9	2386.61	-159.193	-4.44237
# 46828.7	-2351.9	101.165	3.59711
# -2.51998e-09	3.07272e-09	-1.06146e-09	0
# 1.66032e-09	-9.04476e-10	0	0
# -3.9574e-10	0	0	0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Doppler poly
# Polynomial Order: 0 - by - 2
# 0.277228	-523.175	348350
#  Reading in the image
#  At line         1000
#  Interpolating image
#  At line         1000
#  Elapsed time:    8.82421875
# GDAL close: fine_offsets/IW3/range_05.off.vrt
# GDAL close: fine_offsets/IW3/azimuth_05.off.vrt
# GDAL close: ion/lower/fine_interferogram/IW3/secondary_burst_05.slc.vrt
# API close:  ion/lower/fine_interferogram/IW3/secondary_resamp_burst_05.slc
# API open (R): ion/lower/fine_interferogram/IW3/secondary_resamp_burst_05.slc
# API close:  ion/lower/fine_interferogram/IW3/secondary_resamp_burst_05.slc
# Adjust valid samples
# Before:  629 23614
# Offsets :  -39.817527770996094 -36.2902717590332
# Adjust valid lines
# Before:  27 1463
# Offsets :  -2.061539649963379 -2.0390262603759766
# 2024-01-30 11:08:39,653 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1515 which is the number of lines in the slc image.
# 2024-01-30 11:08:39,655 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 24742 which is the width of the slc image.
# 2024-01-30 11:08:39,656 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# No Range Carrier provided.
# Assuming zero range carrier.
# GDAL open (R): ion/upper/fine_interferogram/IW3/secondary_burst_05.slc.vrt
# API open (WR): ion/upper/fine_interferogram/IW3/secondary_resamp_burst_05.slc
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11863.8	-605.413	54.4748	1.35069
# -47140.9	2386.61	-159.193	-4.44237
# 46828.7	-2351.9	101.165	3.59711
# -2.51998e-09	3.07272e-09	-1.06146e-09	0
# 1.66032e-09	-9.04476e-10	0	0
# -3.9574e-10	0	0	0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# GDAL open (R): fine_offsets/IW3/range_05.off.vrt
# GDAL open (R): fine_offsets/IW3/azimuth_05.off.vrt
# Polynomial Order: 0 - by - 2
# 0.277228	-523.175	348350
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#        24742  pixels
#         1515 lines
#
#  Output Image Dimensions:
#        24742 pixels
#         1515 lines
#
#  Number of threads:            8
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 11863.8	-605.413	54.4748	1.35069
# -47140.9	2386.61	-159.193	-4.44237
# 46828.7	-2351.9	101.165	3.59711
# -2.51998e-09	3.07272e-09	-1.06146e-09	0
# 1.66032e-09	-9.04476e-10	0	0
# -3.9574e-10	0	0	0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Doppler poly
# Polynomial Order: 0 - by - 2
# 0.277228	-523.175	348350
#  Reading in the image
#  At line         1000
#  Interpolating image
#  At line         1000
#  Elapsed time:    8.59765625
# GDAL close: fine_offsets/IW3/range_05.off.vrt
# GDAL close: fine_offsets/IW3/azimuth_05.off.vrt
# GDAL close: ion/upper/fine_interferogram/IW3/secondary_burst_05.slc.vrt
# API close:  ion/upper/fine_interferogram/IW3/secondary_resamp_burst_05.slc
# API open (R): ion/upper/fine_interferogram/IW3/secondary_resamp_burst_05.slc
# API close:  ion/upper/fine_interferogram/IW3/secondary_resamp_burst_05.slc
# Adjust valid samples
# Before:  629 23614
# Offsets :  -39.817527770996094 -36.2902717590332
# Adjust valid lines
# Before:  27 1463
# Offsets :  -2.061539649963379 -2.0390262603759766
# processing reference burst: 06, secondary burst: 06, swath: 3
# processing line:   1515 of   1515
#
# processing line:   1000 of   1515
# Chi squared: 0.000193
# Misfit radians - Max: 0.0007005377228779253 , Min : -0.00036651532354881056
# 2024-01-30 11:09:21,928 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1515 which is the number of lines in the slc image.
# 2024-01-30 11:09:21,929 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 24742 which is the width of the slc image.
# 2024-01-30 11:09:21,930 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# processing line:   1515 of   1515
# No Range Carrier provided.
# Assuming zero range carrier.
# file width: 24742, file length: 1515
#
# inputfile byte order: little endian
# input file image offset [byte]: 0
# input file line offset [byte]: 197936
# file width: 24742, file length: 1515
#
# inputfile byte order: little endian
# input file image offset [byte]: 0
# input file line offset [byte]: 197936
# Polynomial Order: 5 - by - 3
# 11894.6	-635.93	66.253	1.52226
# -47200.9	2447.18	-182.474	-4.82493
# 46826.3	-2351.97	101.174	3.59749
# -2.33541e-09	2.65285e-09	-9.02866e-10	0
# 1.57619e-09	-7.84767e-10	0	0
# -3.97385e-10	0	0	0
# GDAL open (R): ion/lower/fine_interferogram/IW3/secondary_burst_06.slc.vrt
# API open (WR): ion/lower/fine_interferogram/IW3/secondary_resamp_burst_06.slc
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11894.6	-635.93	66.253	1.52226
# -47200.9	2447.18	-182.474	-4.82493
# 46826.3	-2351.97	101.174	3.59749
# -2.33541e-09	2.65285e-09	-9.02866e-10	0
# 1.57619e-09	-7.84767e-10	0	0
# -3.97385e-10	0	0	0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# GDAL open (R): fine_offsets/IW3/range_06.off.vrt
# GDAL open (R): fine_offsets/IW3/azimuth_06.off.vrt
# Polynomial Order: 0 - by - 2
# 0.334223	-829.595	490359
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#        24742  pixels
#         1515 lines
#
#  Output Image Dimensions:
#        24742 pixels
#         1515 lines
#
#  Number of threads:            8
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 11894.6	-635.93	66.253	1.52226
# -47200.9	2447.18	-182.474	-4.82493
# 46826.3	-2351.97	101.174	3.59749
# -2.33541e-09	2.65285e-09	-9.02866e-10	0
# 1.57619e-09	-7.84767e-10	0	0
# -3.97385e-10	0	0	0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Doppler poly
# Polynomial Order: 0 - by - 2
# 0.334223	-829.595	490359
#  Reading in the image
#  At line         1000
#  Interpolating image
#  At line         1000
#  Elapsed time:    8.64453125
# GDAL close: fine_offsets/IW3/range_06.off.vrt
# GDAL close: fine_offsets/IW3/azimuth_06.off.vrt
# GDAL close: ion/lower/fine_interferogram/IW3/secondary_burst_06.slc.vrt
# API close:  ion/lower/fine_interferogram/IW3/secondary_resamp_burst_06.slc
# API open (R): ion/lower/fine_interferogram/IW3/secondary_resamp_burst_06.slc
# API close:  ion/lower/fine_interferogram/IW3/secondary_resamp_burst_06.slc
# Adjust valid samples
# Before:  629 23613
# Offsets :  -39.80226516723633 -36.284278869628906
# Adjust valid lines
# Before:  28 1462
# Offsets :  -4.061722755432129 -4.039462089538574
# 2024-01-30 11:09:33,501 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 1515 which is the number of lines in the slc image.
# 2024-01-30 11:09:33,502 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 24742 which is the width of the slc image.
# 2024-01-30 11:09:33,503 - isce.stdproc.resamp_slc - WARNING - No flattening requested
# No Range Carrier provided.
# Assuming zero range carrier.
# GDAL open (R): ion/upper/fine_interferogram/IW3/secondary_burst_06.slc.vrt
# API open (WR): ion/upper/fine_interferogram/IW3/secondary_resamp_burst_06.slc
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 5 - by - 3
# 11894.6	-635.93	66.253	1.52226
# -47200.9	2447.18	-182.474	-4.82493
# 46826.3	-2351.97	101.174	3.59749
# -2.33541e-09	2.65285e-09	-9.02866e-10	0
# 1.57619e-09	-7.84767e-10	0	0
# -3.97385e-10	0	0	0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# GDAL open (R): fine_offsets/IW3/range_06.off.vrt
# GDAL open (R): fine_offsets/IW3/azimuth_06.off.vrt
# Polynomial Order: 0 - by - 2
# 0.334223	-829.595	490359
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#        24742  pixels
#         1515 lines
#
#  Output Image Dimensions:
#        24742 pixels
#         1515 lines
#
#  Number of threads:            8
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 5 - by - 3
# 11894.6	-635.93	66.253	1.52226
# -47200.9	2447.18	-182.474	-4.82493
# 46826.3	-2351.97	101.174	3.59749
# -2.33541e-09	2.65285e-09	-9.02866e-10	0
# 1.57619e-09	-7.84767e-10	0	0
# -3.97385e-10	0	0	0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 0
#  Doppler poly
# Polynomial Order: 0 - by - 2
# 0.334223	-829.595	490359
#  Reading in the image
#  At line         1000
#  Interpolating image
#  At line         1000
#  Elapsed time:    9.04687500
# GDAL close: fine_offsets/IW3/range_06.off.vrt
# GDAL close: fine_offsets/IW3/azimuth_06.off.vrt
# GDAL close: ion/upper/fine_interferogram/IW3/secondary_burst_06.slc.vrt
# API close:  ion/upper/fine_interferogram/IW3/secondary_resamp_burst_06.slc
# API open (R): ion/upper/fine_interferogram/IW3/secondary_resamp_burst_06.slc
# API close:  ion/upper/fine_interferogram/IW3/secondary_resamp_burst_06.slc
# Adjust valid samples
# Before:  629 23613
# Offsets :  -39.80226516723633 -36.284278869628906
# Adjust valid lines
# Before:  28 1462
# Offsets :  -4.061722755432129 -4.039462089538574
# Geo2radar mask IW3 /06: 100%|████████████████████████████████████████████| 17/17 [02:33<00:00,  9.01s/it]
# Masking upper-iono interferograms IW3/06: 100%|██████████████████████████| 34/34 [00:18<00:00,  1.83it/s]
